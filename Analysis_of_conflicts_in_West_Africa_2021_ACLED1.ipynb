# %% [markdown]
# <a href="https://colab.research.google.com/github/obengdouglas/DSI-2022/blob/main/Analysis_of_conflicts_in_West_Africa_2021_ACLED1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analysis of Crisis Events in West Africa 2021 using ACLED data
# ===========================================================

# %% [markdown]
# ## **0. Outline**
#
# 1.	Import Libraries
# 2.	Countries with Highest Number of Conflicts in West Africa, 2021
# 3.	Countries with Highest Number of Fatalities in West Africa, 2021
# 4.	West Africa: Conflicts vs. Fatalities [2021]
# 5.	Map of West African Countries per  with Fatalities
# 6.	Map of West African Countries per Conflicts
# 7.	WorldCloud of most Used Words by News Agencies
# 8.	Causes of Conflicts in West africa, 2021
# 9.	Answer of the Question (What happened in 2021)
# •	Conflicts Reported in Africa in 2021
# •	Fatalities Reported in Africa in 2021
# •	Causes of Conflicts in 2021
# 10.	 Most Popular News Sources in 2021
# 11.	Conflicts & Fatalities by Month in 2021
# 12.	Countries in Conflicts in 2021
#
# 14.	Angola Analysis during 2021
# •	Conflicts Between Actors in Angola
# •	Month vs. Weekday Fatalities Distribution

# %% [markdown]
# ## **1. Introduction**
#
# This project is my submission for the DSI Module 3 Twist Challenge on Natural Language Processing (NLP). For this project, I used open-source data from the Armed Conflict Location & Event Data Project (ACLED.
#
# Armed Conflict Location & Event Data Project (ACLED) is a disaggregated conflict collection, analysis and crisis mapping project. ACLED’s aim is to capture the forms, actors, dates and locations of political violence and protest as it occurs across states. The ACLED team conducts analysis to describe, explore and test conflict scenarios, and makes both data and analysis open to freely use by the public.
#
# This has Conflicts data from 2015 to the present. ACLED collects the dates, actors, types of violence, locations, and fatalities of all reported political violence and protest events across Africa, South Asia, South East Asia and the Middle East. Political violence and protest includes events that occur within civil wars and periods of instability, public protest and regime breakdown.
#
# The project focuses on West Africa for the year 2021. West Africa has 16 countries, 10 of which are french speaking.

# %% [markdown]
# ## **2. Objectives**
#
# The objectives of the project are:
# - Analysis of the crisis events in W/A for 2021 with particular emphasis on event types and fatalities in this notebook (using plotly)
# - Translation of notes coulumn from English to French using huggingface translation transformers. For each event, there is a notes column which has a summary of the details of the event in English. The translation is mainly to aid people in French-speaking West Africa to understand the circumstances of these events.
# - Further analysis of data in Tableau which is flexible for dashboards and deployment. Output from the translation is used for a French labelled dashboard

# %% [markdown]
# ## **3. Import Libraries**

# %%
#!pip install transformers
#!pip install squarify
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib import cm
sns.set_style('ticks')
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
from wordcloud import WordCloud
import os
#from transformers import pipeline #Retrieve pipeline of modules 
import csv
from tqdm import tqdm
import time
from datetime import timedelta

import plotly.io as pio #uncomment if working in colab
pio.renderers.default = "colab" #uncomment if working in colab
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## **4. Read and Manipulate Data**

# %%
#number of rows for 2021 = 8837
acled21 = pd.read_csv('https://raw.githubusercontent.com/obengdouglas/DSI-2022/main/module3-nlp-twist/Data/acled21_westafrica.csv', sep=",", nrows = 8837, skip_blank_lines=True, na_filter=True)
acled21.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  8705324  478       MAA1295              1295  31-Dec-21  2021
# 1  8705857  466       MLI6030              6030  31-Dec-21  2021
# 2  8706204  288       GHA1362              1362  31-Dec-21  2021
# 3  8706259  566      NIG23106             23106  31-Dec-21  2021
# 4  8706524  566      NIG23102             23102  31-Dec-21  2021
#
#    time_precision event_type         sub_event_type  \
# 0               2   Protests       Peaceful protest
# 1               1    Battles            Armed clash
# 2               1    Battles            Armed clash
# 3               1      Riots           Mob violence
# 4               1      Riots  Violent demonstration
#
#                              actor1  ...      location  latitude longitude  \
# 0           Protesters (Mauritania)  ...    Nouakchott   18.0801  -15.9777
# 1   Military Forces of Mali (2021-)  ...  Diangassagou   13.9964   -3.9414
# 2  Unidentified Armed Group (Ghana)  ...         Accra    5.5560   -0.1969
# 3                 Rioters (Nigeria)  ...       Oshogbo    7.7667    4.5667
# 4                 Rioters (Nigeria)  ...        Bogoro    9.6667    9.6000
#
#   geo_precision            source  source_scale  \
# 0             1        Adrar Info      National
# 1             2          FAMAMali      National
# 2             1     My Joy Online   Subnational
# 3             1     Nigeria Punch      National
# 4             1  Sahara Reporters      Regional
#
#                                                notes fatalities   timestamp  \
# 0  Around 31 December 2021 (as reported), credito...          0  1641863885
# 1  On 31 December 2021, the Malian army foiled an...         16  1641863886
# 2  On 31 December 2021, gunmen clashed with priva...          0  1641863887
# 3  On 31 December 2021, a mob attacked Amotekun o...          1  1641863887
# 4  On 31 December 2021, a mob demonstrated and de...          0  1641863887
#
#   iso3
# 0  MRT
# 1  MLI
# 2  GHA
# 3  NGA
# 4  NGA
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 4.1  Lowercase headers

# %%
# Lowercase all the columns name
acled21.rename(str.lower, axis = 'columns', inplace = True)
# checking for null Values in percent
round((acled21.isnull().sum()/acled21.shape[0])*100,2)
# Out:
# data_id              0.00
# iso                  0.00
# event_id_cnty        0.00
# event_id_no_cnty     0.00
# event_date           0.00
# year                 0.00
# time_precision       0.00
# event_type           0.00
# sub_event_type       0.00
# actor1               0.00
# assoc_actor_1       68.17
# inter1               0.00
# actor2              19.41
# assoc_actor_2       68.75
# inter2               0.00
# interaction          0.00
# region               0.00
# country              0.00
# admin1               0.01
# admin2               0.01
# admin3              47.41
# location             0.00
# latitude             0.00
# longitude            0.00
# geo_precision        0.00
# source               0.00
# source_scale         0.00
# notes                0.00
# fatalities           0.00
# timestamp            0.00
# iso3                 0.00
# year_extract         0.00
# month                0.00
# day of week          0.00
# dtype: float64

# %% [markdown]
# ### 4.2  Get Month, Day from datetime

# %%
# Convert Event date from a str to datetime format
acled21.event_date = pd.to_datetime(acled21.event_date)
#Let extract Month, and ,years
acled21['year_extract']= acled21['event_date'].apply(lambda x: x.year) #this will extract years from the event_date format
acled21['month']= acled21['event_date'].apply(lambda x: x.month) #this will extract Month from the event_date format
acled21['day of week']= acled21['event_date'].apply(lambda x: x.dayofweek)
dmonth = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',
         9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
acled21['month'] = acled21['month'].map(dmonth)
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
acled21['day of week']= acled21['day of week'].map(dmap)
acled21.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  8705324  478       MAA1295              1295 2021-12-31  2021
# 1  8705857  466       MLI6030              6030 2021-12-31  2021
# 2  8706204  288       GHA1362              1362 2021-12-31  2021
# 3  8706259  566      NIG23106             23106 2021-12-31  2021
# 4  8706524  566      NIG23102             23102 2021-12-31  2021
#
#    time_precision event_type         sub_event_type  \
# 0               2   Protests       Peaceful protest
# 1               1    Battles            Armed clash
# 2               1    Battles            Armed clash
# 3               1      Riots           Mob violence
# 4               1      Riots  Violent demonstration
#
#                              actor1  ... geo_precision            source  \
# 0           Protesters (Mauritania)  ...             1        Adrar Info
# 1   Military Forces of Mali (2021-)  ...             2          FAMAMali
# 2  Unidentified Armed Group (Ghana)  ...             1     My Joy Online
# 3                 Rioters (Nigeria)  ...             1     Nigeria Punch
# 4                 Rioters (Nigeria)  ...             1  Sahara Reporters
#
#   source_scale                                              notes  fatalities  \
# 0     National  Around 31 December 2021 (as reported), credito...           0
# 1     National  On 31 December 2021, the Malian army foiled an...          16
# 2  Subnational  On 31 December 2021, gunmen clashed with priva...           0
# 3     National  On 31 December 2021, a mob attacked Amotekun o...           1
# 4     Regional  On 31 December 2021, a mob demonstrated and de...           0
#
#     timestamp iso3 year_extract month day of week
# 0  1641863885  MRT         2021   Dec         Fri
# 1  1641863886  MLI         2021   Dec         Fri
# 2  1641863887  GHA         2021   Dec         Fri
# 3  1641863887  NGA         2021   Dec         Fri
# 4  1641863887  NGA         2021   Dec         Fri
#
# [5 rows x 34 columns]

# %% [markdown]
# ## **5. Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### 5.1 Countries with the Highest number of Conflicts

# %%
#change a long country name to an alias

acled21.country.value_counts().head()
data_1 = acled21.country.value_counts().sort_values(ascending=False)
x=data_1.index
y= data_1.values

trace1 = go.Bar(
    x=x,
    y=y,
    text = y,
    textposition = 'auto',
    textfont = {'size':12,'color':'black'},
    marker=dict(
    color='SlateGray'),
    opacity=0.8,
    orientation ='v',
)

data = [trace1]

layout = go.Layout (
    yaxis = dict (
    title = 'Numbers of Conflitc'),
    
    xaxis = dict (
    title = 'Country'),
    
    title = 'Top 10 Countries with Highest Conflicts'
)
fig = go.Figure (data=data, layout = layout)
py.iplot(fig)


## Analysis: The top 3 crisis events countries are Nigeria, Burkina Faso and Mali accounting for 42%, 21% and 15% respectively of all events in West Africa. Together, they account for 78% of all crisis events.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="539e8f65-e6ab-4ee8-a250-b15afb2d45b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("539e8f65-e6ab-4ee8-a250-b15afb2d45b8")) {                    Plotly.newPlot(                        "539e8f65-e6ab-4ee8-a250-b15afb2d45b8",                        [{"marker":{"color":"SlateGray"},"opacity":0.8,"orientation":"v","text":[3733.0,1850.0,1352.0,430.0,282.0,227.0,222.0,203.0,162.0,158.0,55.0,54.0,35.0,28.0,27.0,19.0],"textfont":{"color":"black","size":12},"textposition":"auto","x":["Nigeria","Burkina Faso","Mali","Niger","Mauritania","Guinea","Ivory Coast","Senegal","Benin","Ghana","Cape Verde","Liberia","Togo","Sierra Leone","Gambia","Guinea-Bissau"],"y":[3733,1850,1352,430,282,227,222,203,162,158,55,54,35,28,27,19],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automar ...

# %% [markdown]
# ### 5.2 Countries with the highest Number of Fatalities

# %%
data_2 = acled21.groupby('country')['fatalities'].sum().sort_values(ascending=False)
x=data_2.index
y= data_2.values

trace1 = go.Bar(
    x=x,
    y=y,
    text = y,
    textposition = 'auto',
    textfont = {'size':18,'color':'blue'},
    marker=dict(
    color='darkred'),
    opacity=0.8,
    orientation ='v',
)

data = [trace1]

layout = go.Layout (
    
    xaxis = dict (
    title = 'Countries Name'),
    
    title = 'Countries with Highest Fatalities'
)
fig = go.Figure (data=data, layout = layout)
py.iplot(fig)


## Analysis: The top 3 crisis countries for fatalities are Nigeria, Burkina Faso and Mali accounting for 62%, 15% and 12% respectively of all fatalities in West Africa. Together, they account for 89% of all fatalities.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4c8b41f9-1cf3-4b98-b20b-279391baf706" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c8b41f9-1cf3-4b98-b20b-279391baf706")) {                    Plotly.newPlot(                        "4c8b41f9-1cf3-4b98-b20b-279391baf706",                        [{"marker":{"color":"darkred"},"opacity":0.8,"orientation":"v","text":[9914.0,2373.0,1905.0,1460.0,93.0,38.0,38.0,28.0,24.0,7.0,4.0,2.0,1.0,1.0,0.0,0.0],"textfont":{"color":"blue","size":18},"textposition":"auto","x":["Nigeria","Burkina Faso","Mali","Niger","Benin","Ghana","Ivory Coast","Guinea","Senegal","Liberia","Togo","Sierra Leone","Gambia","Mauritania","Cape Verde","Guinea-Bissau"],"y":[9914,2373,1905,1460,93,38,38,28,24,7,4,2,1,1,0,0],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"s ...

# %% [markdown]
# ### 5.3 Fatality per event rate

# %%
data_2 = acled21.groupby('country')['fatalities'].sum().sort_values(ascending=False)
x=data_2.index

y= np.round(data_2.values/data_1.values, decimals=2)

trace1 = go.Bar(
    x=x,
    y=y,
    text = y,
    textposition = 'auto',
    textfont = {'size':18,'color':'blue'},
    marker=dict(
    color='darkred'),
    opacity=0.8,
    orientation ='v',
)

data = [trace1]

layout = go.Layout (
    
    xaxis = dict (
    title = 'Country'),
    
    title = 'Fatalities per crisis event in West Africa, 2021'
)
fig = go.Figure (data=data, layout = layout)
py.iplot(fig)

## Analysis: 4 countries have >1 fatality per event led by Niger and Nigeria. Order of countries not sorted in order to match countries with previous plots
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="160c6478-5895-4271-9d96-2ffad3cc0917" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("160c6478-5895-4271-9d96-2ffad3cc0917")) {                    Plotly.newPlot(                        "160c6478-5895-4271-9d96-2ffad3cc0917",                        [{"marker":{"color":"darkred"},"opacity":0.8,"orientation":"v","text":[2.66,1.28,1.41,3.4,0.33,0.17,0.17,0.14,0.15,0.04,0.07,0.04,0.03,0.04,0.0,0.0],"textfont":{"color":"blue","size":18},"textposition":"auto","x":["Nigeria","Burkina Faso","Mali","Niger","Benin","Ghana","Ivory Coast","Guinea","Senegal","Liberia","Togo","Sierra Leone","Gambia","Mauritania","Cape Verde","Guinea-Bissau"],"y":[2.66,1.28,1.41,3.4,0.33,0.17,0.17,0.14,0.15,0.04,0.07,0.04,0.03,0.04,0.0,0.0],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin ...

# %% [markdown]
# ### 5.4 Map of West Africa: Fatalities per Country

# %%
rt = acled21.groupby('country').sum()['fatalities'].sort_values(ascending=False)

data = [dict(
        type='choropleth',
        locations= rt.index,
        locationmode='country names',
        z=rt.values,
        text=rt.index,
        colorscale='Reds',
        marker=dict(line=dict(width=0.7)),
        colorbar=dict(autotick=False, tickprefix='', title=' Fatalities Scale'),
)]
layout = dict(title = 'Fatalities reported in Africa [2021]',
             geo = dict(
            showframe = True,
            showcoastlines = False,
            projection = dict(
                type = 'Mercator'
            )
        ),)
fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False)


## Analysis: Nigeria is a clear outlier on the fatalities map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="255a5094-1c84-4b56-84c9-6c56d303fb58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("255a5094-1c84-4b56-84c9-6c56d303fb58")) {                    Plotly.newPlot(                        "255a5094-1c84-4b56-84c9-6c56d303fb58",                        [{"type":"choropleth","locations":["Nigeria","Burkina Faso","Mali","Niger","Benin","Ghana","Ivory Coast","Guinea","Senegal","Liberia","Togo","Sierra Leone","Gambia","Mauritania","Cape Verde","Guinea-Bissau"],"locationmode":"country names","z":[9914,2373,1905,1460,93,38,38,28,24,7,4,2,1,1,0,0],"text":["Nigeria","Burkina Faso","Mali","Niger","Benin","Ghana","Ivory Coast","Guinea","Senegal","Liberia","Togo","Sierra Leone","Gambia","Mauritania","Cape Verde","Guinea-Bissau"],"colorscale":"Reds","marker":{"line":{"width":0.7}},"colorbar":{"autotick":false,"tickprefix":"","title":" Fatalities Scale"}}],                        {"title":"Fatalities reported in Africa [2021]","geo":{"showframe":true,"showcoastlines":false,"projection":{"type":"Mercator"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('255a5094-1c84-4b56-84c9-6c56d303fb58');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ### 5.5 Map of West Africa: Conflicts per country

# %%
rt2 = acled21.country.value_counts().sort_values(ascending=False)

data = [dict(
        type='choropleth',
        locations= rt2.index,
        locationmode='country names',
        z=rt2.values,
        text=rt2.index,
        colorscale='Reds',
        marker=dict(line=dict(width=0.7)),
        colorbar=dict(autotick=False, tickprefix='', title=' Countries with Conflicts'),
)]
layout = dict(title = 'Conflicts reported in Africa [2021]',
             geo = dict(
            showframe = True,
            showcoastlines = False,
            projection = dict(
                type = 'Mercator'
            )
        ),)
fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False)

## Analysis: Nigeria is a clear outlier on the crisis events map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="36f0b78e-ff1b-404d-ab9c-e358cc97fa9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36f0b78e-ff1b-404d-ab9c-e358cc97fa9f")) {                    Plotly.newPlot(                        "36f0b78e-ff1b-404d-ab9c-e358cc97fa9f",                        [{"type":"choropleth","locations":["Nigeria","Burkina Faso","Mali","Niger","Mauritania","Guinea","Ivory Coast","Senegal","Benin","Ghana","Cape Verde","Liberia","Togo","Sierra Leone","Gambia","Guinea-Bissau"],"locationmode":"country names","z":[3733,1850,1352,430,282,227,222,203,162,158,55,54,35,28,27,19],"text":["Nigeria","Burkina Faso","Mali","Niger","Mauritania","Guinea","Ivory Coast","Senegal","Benin","Ghana","Cape Verde","Liberia","Togo","Sierra Leone","Gambia","Guinea-Bissau"],"colorscale":"Reds","marker":{"line":{"width":0.7}},"colorbar":{"autotick":false,"tickprefix":"","title":" Countries with Conflicts"}}],                        {"title":"Conflicts reported in Africa [2021]","geo":{"showframe":true,"showcoastlines":false,"projection":{"type":"Mercator"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('36f0b78e-ff1b-404d-ab9c-e358cc97fa9f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ### 5.6 WordCloud of most used Words by the News Report Agencies

# %%
#clean data
import re
from nltk.corpus import stopwords
clean_1 = re.compile('[/(){}\[\]\|@,;]')
clean_2 = re.compile('[^0-9a-z #+_]')
def clean_text (text):
    text = text.lower()
    text = clean_1.sub(' ',text) # compile and replace those symbole by empty scpace
    text = clean_2.sub('',text)
    text_2 = [word.strip() for word in text.split() if not word in set(stopwords.words('english'))]
    new_text = ''
    for i in text_2:
        new_text +=i+' '
    text = new_text
    return text.strip()

# remove null value from column 'notes'
temp1 = acled21.dropna(subset=['notes'])
temp1['notes'] = temp1['notes'].apply(lambda x: " ".join(x.lower() for x in x.split()))
temp1['notes'] = temp1['notes'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

from wordcloud import WordCloud

wc = WordCloud(max_font_size=50, width=600, height=300,colormap='Blues')
wc.generate(' '.join(temp1['notes'].values))

plt.figure(figsize=(30,15))
plt.imshow(wc,interpolation="bilinear")
plt.title("Most Used Words by News Report Agencies", fontsize=35)
plt.axis("off")
plt.show() 


## Analysis: Most used words include sizeno report, jnim militant (Mali), militant, militia and village

# %% [markdown]
# ### 5.7. Causes of Conflicts in West Africa

# %%
# Lower all word in event_type
acled21.event_type = acled21.event_type.apply(lambda x: x.lower())
event_data = acled21.groupby('event_type').sum().reset_index()
# Create a new columns that count the numbers of counflicts 
d = dict(acled21.event_type.value_counts())
event_data['conflicts'] = event_data['event_type'].map(d)
# Sort the data by Fatalities
event_data.sort_values(by='fatalities', ascending=False,inplace=True)
#reduce the data to only 8 event type
event_data = event_data.head(8)

# %%
f, ax = plt.subplots(1,1,figsize = (10,10))
ax = event_data[['fatalities', 'conflicts']].plot(kind='barh',ax=ax,width=0.8,
              color=['dodgerblue', 'slategray'], fontsize=13);

ax.set_title("Causes of Conflicts in West Africa",fontsize=20)
ax.set_ylabel("Event Type", fontsize=15)

ax.set_yticklabels(event_data.event_type.values)

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+750, i.get_y()+.25, \
            str(int(round(((i.get_width()))))), fontsize=15, color='black')

# invert for largest on top 
ax.invert_yaxis()
sns.despine(bottom=True)
x_axis = ax.axes.get_xaxis().set_visible(False) # turn off the y axis label
plt.legend(loc=(1.0,0.98),fontsize=13,ncol=2)
plt.show()


## Analysis: Battles, violence against civilians and explosions lead to the highest numbers of fatalities. Battles lead to a disproportionately high incidence of fatalities.

# %% [markdown]
# ### 5.8 Most Popular News Sources in 2021

# %%
source_21 = acled21.source.value_counts().head(10)
f, ax = plt.subplots(1,1,figsize = (10,10))

ax.barh(source_21.index,source_21.values,color='DarkCyan',edgecolor='black')
ax.set_title("Top 10 News Source in 2021 ",
fontsize=15)

ax.set_ylabel("News Source", fontsize=15)
ax.tick_params(length=3, width=1, colors='black',labelsize='large',axis='y')
ax.set_yticklabels(source_21.index)

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+4, i.get_y()+ 0.51, \
            str(round((i.get_width()),2)), fontsize=12, color='black')

# invert for largest on top 
ax.invert_yaxis()
sns.despine(bottom=True)
x_axis = ax.axes.get_xaxis().set_visible(False) # turn off the y axis label
plt.show()


## Analysis: The top news source belongs to undisclosed category. This is followed by signal (an open-source secure messaging app) and 3 Nigerian media houses.

# %% [markdown]
# ### 5.9 Conflicts Between Actors

# %%
actor = acled21.groupby(['actor1','actor2']).sum()['fatalities'].reset_index().sort_values('fatalities',ascending=False).head(20)

# %%
actors= actor.pivot_table(index='actor1',columns='actor2',values='fatalities',aggfunc='sum')

f, ax = plt.subplots(figsize=(15,7))

ax = sns.heatmap(actors, cmap='Reds',linecolor='black',linewidths=0.2,annot=True,fmt='.1f',annot_kws={'fontsize':15})

ax.tick_params(axis = 'y',length=3, width=1, colors='black',labelsize=13)
ax.tick_params(axis = 'x',length=3, width=1, colors='black',labelsize=13)
kwargs= {'fontsize':15, 'color':'black'}
ax.set_xlabel('Actor2',**kwargs)
ax.set_ylabel('Actor1',**kwargs)
ax.set_title('Fatalities btw Actors in West Africa conflicts',fontsize=20, color='black')
sns.despine(top=False,right = False)
plt.show()


## Analysis: Conflict between the military Forces of Nigeria and the Islamic State West Africa lead in the number of fatalities

# %% [markdown]
# ### 5.10 Month vs. Weekday Fatalities Distribution

# %%
week_month_1= acled21.pivot_table(index='month',columns='day of week',values='fatalities',aggfunc='sum')
#Sorting the month Chronologically
week_month_1.index = pd.CategoricalIndex(week_month_1.index,
        categories= ['Jan', 'Feb', 'Mar', 'Apr','May','Jun', 'Jul', 'Aug','Sep', 'Oct', 'Nov', 'Dec'])
week_month_1 = week_month_1.sort_index()
f, ax = plt.subplots(figsize=(15,10))

ax = sns.heatmap(week_month_1, cmap='gist_heat_r',linecolor='black',linewidths=0.4,annot=True,fmt='.1f',annot_kws={'fontsize':13})
ax.tick_params(axis = 'y',length=3, width=1, colors='black',labelsize=13)
ax.tick_params(axis = 'x',length=3, width=1, colors='black',labelsize=13)
kwargs= {'fontsize':13, 'color':'black'}
ax.set_xlabel('Day of Week',**kwargs)
ax.set_ylabel('Months',**kwargs)
ax.set_title('Months vs. Weekday Fatalities Distribution in West Africa',fontsize=20, color = 'black')
sns.despine(top=False,right = False)
plt.show()


## Analysis: There is no clear pattern either in the month of the year or day of the week. However, September 2021 seems to have recorded fewer fatalities than the other months

# %% [markdown]
# ## **6. Machine Translation of labels/notes from English to French (October - December, 2021 only)**

# %% [markdown]
# ### 6.1 Download huggingface translator transformer

# %%
#Choose English to French translation
translator = pipeline("translation_en_to_fr")
# Out:
# No model was supplied, defaulted to t5-base (https://huggingface.co/t5-base)
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]

# %% [markdown]
# ### 6.2. Read last 3 months of 2021 for translation

# %%
#read csv file from github repo. Same file for 2021; top 2378 rows represent 4th quarter 2021 (Oct - Dec)
acled21_fr = pd.read_csv('https://raw.githubusercontent.com/obengdouglas/DSI-2022/main/module3-nlp-twist/Data/acled21_westafrica.csv', sep=",", nrows = 2378, skip_blank_lines=True, na_filter=True)
acled21_fr.tail()
# Out:
#       data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 2373  8597141  466       MLI5752              5752  01-Oct-21  2021
# 2374  8605877  566      NIG22279             22279  01-Oct-21  2021
# 2375  8667002  566      NIG22158             22158  01-Oct-21  2021
# 2376  8667188  566      NIG22160             22160  01-Oct-21  2021
# 2377  8843364  854       BFO5413              5413  01-Oct-21  2021
#
#       time_precision                  event_type  \
# 2373               1  Violence against civilians
# 2374               1      Strategic developments
# 2375               1  Explosions/Remote violence
# 2376               1                     Battles
# 2377               1  Violence against civilians
#
#                          sub_event_type  \
# 2373                             Attack
# 2374       Looting/property destruction
# 2375  Shelling/artillery/missile attack
# 2376                        Armed clash
# 2377                             Attack
#
#                                                  actor1  ... location  \
# 2373  Islamic State (West Africa) - Greater Sahara F...  ...  Lelehoy
# 2374                    Fulani Ethnic Militia (Nigeria)  ...    Itori
# 2375    Islamic State (West Africa) - Lake Chad Faction  ...     Bama
# 2376                 Military Forces of Nigeria (2015-)  ...    Gwoza
# 2377  Islamic State (West Africa) - Greater Sahara F...  ...  Goungam
#
#       latitude longitude geo_precision                       source  \
# 2373   15.5557    0.4944             1              UN MINUSMA; RFI
# 2374    6.9306    3.2209             2                Nigeria Punch
# 2375   11.5221   13.6856             1  Twitter; Undisclosed Source
# 2376   11.0840   13.6925             2                      Twitter
# 2377   14.7014    0.0929             1           Facebook; Whatsapp
#
#              source_scale                                              notes  \
# 2373  Other-International  On 1 October 2021, ISWAP (Greater Sahara) mili...
# 2374             National  Property destruction: On 1 October 2021, suspe...
# 2375  Local partner-Other  On 1 October 2021, ISWAP claimed a mortar shel...
# 2376            New media  On 1 October 2021, Nigerian troops clashed wit...
# 2377            New media  On 1 October 2021, presumed ISWAP (Greater Sah...
#
#      fatalities   timestamp iso3
# 2373          0  1634581156  MLI
# 2374          0  1635193321  NGA
# 2375          0  1638292281  NGA
# 2376          3  1638292282  NGA
# 2377          7  1645032563  BFA
#
# [5 rows x 31 columns]

# %%
acled21_fr.describe()
# Out:
#             data_id          iso  event_id_no_cnty    year  time_precision  \
# count  2.378000e+03  2378.000000       2378.000000  2378.0     2378.000000
# mean   8.669457e+06   610.080740      12043.520606  2021.0        1.061817
# std    6.680761e+04   178.497832       8732.439043     0.0        0.244341
# min    8.574582e+06   132.000000        105.000000  2021.0        1.000000
# 25%    8.612427e+06   478.000000       5663.250000  2021.0        1.000000
# 50%    8.663554e+06   566.000000       6007.000000  2021.0        1.000000
# 75%    8.704876e+06   854.000000      22478.750000  2021.0        1.000000
# max    9.106989e+06   854.000000      24085.000000  2021.0        3.000000
#
#             inter1       inter2  interaction     latitude    longitude  \
# count  2378.000000  2378.000000  2378.000000  2378.000000  2378.000000
# mean      3.297729     3.946594    32.957527    11.295017     1.185635
# std       1.813938     2.988001    17.363988     3.482415     6.789494
# min       1.000000     0.000000    10.000000     4.323400   -24.985100
# 25%       2.000000     1.000000    16.000000     8.366700    -2.776400
# 50%       3.000000     4.000000    27.000000    12.067150     0.822800
# 75%       5.000000     7.000000    47.000000    13.831700     6.733900
# max       8.000000     8.000000    78.000000    25.140000    14.472400
#
#        geo_precision   fatalities     timestamp
# count    2378.000000  2378.000000  2.378000e+03
# mean        1.412952     1.622792  1.638478e+09
# std         0.503451     5.549284  3.060887e+06
# min         1.000000     0.000000  1.633377e+09
# 25%         1.000000     0.000000  1.635799e+09
# 50%         1.000000     0.000000  1.638225e+09
# 75%         2.000000     1.000000  1.641864e+09
# max         3.000000    87.000000  1.650317e+09

# %%
start_time = time.monotonic() #measure time it takes to complete operation

# %%
#NB: The translator operation takes a long time to complete (check example time below). 
#tqdm.pandas() # shows progress bar for operation
#acled21_fr["notes_fr"] = acled.notes.progress_apply(translator)
#acled21_fr.head()


## Time for translating Q1 2022 in colaboratery (3005 rows) 8hrs 7mins 36secs - 9.74s/it
## Time for translating Q4 2021 in kaggle (2378 rows) 3hrs 49mins 22secs - 5.79s/it
# Out:
# 100%|██████████| 3005/3005 [8:07:36<00:00,  9.74s/it]
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  8974302  854       BFO6949              6949  31-Mar-22  2022
# 1  8974306  854       BFO6964              6964  31-Mar-22  2022
# 2  8974377  566      NIG24258             24258  31-Mar-22  2022
# 3  8974378  566      NIG24259             24259  31-Mar-22  2022
# 4  8974400  566      NIG24300             24300  31-Mar-22  2022
#
#    time_precision                  event_type                sub_event_type  \
# 0               1  Violence against civilians                        Attack
# 1               1      Strategic developments  Looting/property destruction
# 2               2                     Battles                   Armed clash
# 3               1                     Battles                   Armed clash
# 4               1      Strategic developments         Disrupted weapons use
#
#                                               actor1  ... latitude  longitude  \
# 0  JNIM: Group for Support of Islam and Muslims a...  ...  13.6451    -0.7156
# 1       JNIM: Group for Support of Islam and Muslims  ...  11.9333     1.6167
# 2  Boko Haram - Jamaatu Ahli is-Sunnah lid-Dawati...  ...  13.6169    13.2644
# 3                 Unidentified Armed Group (Nigeria)  ...   6.2658     6.5973
# 4                   Police Forces of Nigeria (2015-)  ...  10.5422     7.3302
#
#   geo_precision                                             source  \
# 0             2  Facebook; L'Observateur Paalga; Infowakat; Min...
# 1             1           Gulmu Info; Facebook; Undisclosed Source
# 2             2  Daily Post (Nigeria); Sahara Reporters; Daily ...
# 3             2                  Nigeria Punch; Guardian (Nigeria)
# 4             1  Sahara Reporters; Daily Trust (Nigeria); Niger...
#
#           source_scale                                              notes  \
# 0   New media-National  On 31 March 2022, presumed JNIM or IS Sahel mi...
# 1  Local partner-Other  Looting: On 31 March 2022, presumed JNIM milit...
# 2    National-Regional  Around 31 March 2022 (as reported), Boko Haram...
# 3             National  On 31 March 2022, armed individuals attacked s...
# 4    National-Regional  Defusal: On 31 March 2022, operatives of the a...
#
#   fatalities   timestamp iso3  \
# 0         20  1649088162  BFA
# 1          0  1649088162  BFA
# 2         20  1649088162  NGA
# 3          1  1649088162  NGA
# 4          0  1649088162  NGA
#
#                                             notes_fr
# 0  [{'translation_text': 'Le 31 mars 2022, des mi...
# 1  [{'translation_text': 'Le pillage : Le 31 mars...
# 2  [{'translation_text': 'Vers le 31 mars 2022 (t...
# 3  [{'translation_text': 'Le 31 mars 2022, des in...
# 4  [{'translation_text': 'Défaut : Le 31 mars 202...
#
# [5 rows x 32 columns]

# %%
end_time = time.monotonic()
print(timedelta(seconds=end_time - start_time))
# Out:
# 8:07:36.885580

# %%
#Save dataframe as csv. NB: Output saved in github repo https://github.com/obengdouglas/DSI-2022/tree/main/module3-nlp-twist/Data as acled_fr.csv
acled21_fr.to_csv("acled21_fr.csv", index = False) #NB: Change excel csv format to unicode UTF-8 in order to properly display french accented characters

# %%
#Read acled21_fr from github if notebook session has ended
acled21_fr = pd.read_csv('https://raw.githubusercontent.com/obengdouglas/DSI-2022/main/module3-nlp-twist/Data/acled21_fr.csv', sep=",", nrows = 2378, skip_blank_lines=True, na_filter=True)
acled21_fr.tail()
# Out:
#       data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 2373  8597141  466       MLI5752              5752  01-Oct-21  2021
# 2374  8605877  566      NIG22279             22279  01-Oct-21  2021
# 2375  8667002  566      NIG22158             22158  01-Oct-21  2021
# 2376  8667188  566      NIG22160             22160  01-Oct-21  2021
# 2377  8843364  854       BFO5413              5413  01-Oct-21  2021
#
#       time_precision                  event_type  \
# 2373               1  Violence against civilians
# 2374               1      Strategic developments
# 2375               1  Explosions/Remote violence
# 2376               1                     Battles
# 2377               1  Violence against civilians
#
#                          sub_event_type  \
# 2373                             Attack
# 2374       Looting/property destruction
# 2375  Shelling/artillery/missile attack
# 2376                        Armed clash
# 2377                             Attack
#
#                                                  actor1  ... latitude  \
# 2373  Islamic State (West Africa) - Greater Sahara F...  ...  15.5557
# 2374                    Fulani Ethnic Militia (Nigeria)  ...   6.9306
# 2375    Islamic State (West Africa) - Lake Chad Faction  ...  11.5221
# 2376                 Military Forces of Nigeria (2015-)  ...  11.0840
# 2377  Islamic State (West Africa) - Greater Sahara F...  ...  14.7014
#
#       longitude geo_precision                       source  \
# 2373     0.4944             1              UN MINUSMA; RFI
# 2374     3.2209             2                Nigeria Punch
# 2375    13.6856             1  Twitter; Undisclosed Source
# 2376    13.6925             2                      Twitter
# 2377     0.0929             1           Facebook; Whatsapp
#
#              source_scale                                              notes  \
# 2373  Other-International  On 1 October 2021, ISWAP (Greater Sahara) mili...
# 2374             National  Property destruction: On 1 October 2021, suspe...
# 2375  Local partner-Other  On 1 October 2021, ISWAP claimed a mortar shel...
# 2376            New media  On 1 October 2021, Nigerian troops clashed wit...
# 2377            New media  On 1 October 2021, presumed ISWAP (Greater Sah...
#
#      fatalities   timestamp iso3  \
# 2373          0  1634581156  MLI
# 2374          0  1635193321  NGA
# 2375          0  1638292281  NGA
# 2376          3  1638292282  NGA
# 2377          7  1645032563  BFA
#
#                                                notes_fr
# 2373  [{'translation_text': "Le 1er octobre 2021, de...
# 2374  [{'translation_text': "Destruction de biens : ...
# 2375  [{'translation_text': "Le 1er octobre 2021, l'...
# 2376  [{'translation_text': "Le 1er octobre 2021, de...
# 2377  [{'translation_text': "Le 1er octobre 2021, de...
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 6.3 Clean french results

# %%
#remove "[translation_text" at the beginning of french translations (notes_fr)
acled21_fr["notes_fr"] = acled21_fr["notes_fr"].str.replace("\[{'translation_text': \"", "")
acled21_fr["notes_fr"] = acled21_fr["notes_fr"].str.replace("\[{\'translation_text\': \'", "")
acled21_fr["notes_fr"] = acled21_fr["notes_fr"].str.replace("\"}]", "")
acled21_fr["notes_fr"] = acled21_fr["notes_fr"].str.replace("\'}]", "")

acled21_fr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  8705324  478       MAA1295              1295  31-Dec-21  2021
# 1  8705857  466       MLI6030              6030  31-Dec-21  2021
# 2  8706204  288       GHA1362              1362  31-Dec-21  2021
# 3  8706259  566      NIG23106             23106  31-Dec-21  2021
# 4  8706524  566      NIG23102             23102  31-Dec-21  2021
#
#    time_precision event_type         sub_event_type  \
# 0               2   Protests       Peaceful protest
# 1               1    Battles            Armed clash
# 2               1    Battles            Armed clash
# 3               1      Riots           Mob violence
# 4               1      Riots  Violent demonstration
#
#                              actor1  ... latitude  longitude geo_precision  \
# 0           Protesters (Mauritania)  ...  18.0801   -15.9777             1
# 1   Military Forces of Mali (2021-)  ...  13.9964    -3.9414             2
# 2  Unidentified Armed Group (Ghana)  ...   5.5560    -0.1969             1
# 3                 Rioters (Nigeria)  ...   7.7667     4.5667             1
# 4                 Rioters (Nigeria)  ...   9.6667     9.6000             1
#
#              source  source_scale  \
# 0        Adrar Info      National
# 1          FAMAMali      National
# 2     My Joy Online   Subnational
# 3     Nigeria Punch      National
# 4  Sahara Reporters      Regional
#
#                                                notes fatalities   timestamp  \
# 0  Around 31 December 2021 (as reported), credito...          0  1641863885
# 1  On 31 December 2021, the Malian army foiled an...         16  1641863886
# 2  On 31 December 2021, gunmen clashed with priva...          0  1641863887
# 3  On 31 December 2021, a mob attacked Amotekun o...          1  1641863887
# 4  On 31 December 2021, a mob demonstrated and de...          0  1641863887
#
#   iso3                                           notes_fr
# 0  MRT  Vers le 31 décembre 2021 (comme on l'a signalé...
# 1  MLI  Le 31 décembre 2021, l'armée malienne a échoué...
# 2  GHA  Le 31 décembre 2021, des hommes armés ont eu d...
# 3  NGA  Le 31 décembre 2021, une foule a attaqué des a...
# 4  NGA  Le 31 décembre 2021, une foule a démontré et d...
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 6.4 Append French notes to original acled full year 2021 dataframe

# %%
notes_fr=acled21_fr['notes_fr']
acled21_final = acled21.join(notes_fr)
acled21_final.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  8705324  478       MAA1295              1295  31-Dec-21  2021
# 1  8705857  466       MLI6030              6030  31-Dec-21  2021
# 2  8706204  288       GHA1362              1362  31-Dec-21  2021
# 3  8706259  566      NIG23106             23106  31-Dec-21  2021
# 4  8706524  566      NIG23102             23102  31-Dec-21  2021
#
#    time_precision event_type         sub_event_type  \
# 0               2   Protests       Peaceful protest
# 1               1    Battles            Armed clash
# 2               1    Battles            Armed clash
# 3               1      Riots           Mob violence
# 4               1      Riots  Violent demonstration
#
#                              actor1  ... latitude  longitude geo_precision  \
# 0           Protesters (Mauritania)  ...  18.0801   -15.9777             1
# 1   Military Forces of Mali (2021-)  ...  13.9964    -3.9414             2
# 2  Unidentified Armed Group (Ghana)  ...   5.5560    -0.1969             1
# 3                 Rioters (Nigeria)  ...   7.7667     4.5667             1
# 4                 Rioters (Nigeria)  ...   9.6667     9.6000             1
#
#              source  source_scale  \
# 0        Adrar Info      National
# 1          FAMAMali      National
# 2     My Joy Online   Subnational
# 3     Nigeria Punch      National
# 4  Sahara Reporters      Regional
#
#                                                notes fatalities   timestamp  \
# 0  Around 31 December 2021 (as reported), credito...          0  1641863885
# 1  On 31 December 2021, the Malian army foiled an...         16  1641863886
# 2  On 31 December 2021, gunmen clashed with priva...          0  1641863887
# 3  On 31 December 2021, a mob attacked Amotekun o...          1  1641863887
# 4  On 31 December 2021, a mob demonstrated and de...          0  1641863887
#
#   iso3                                           notes_fr
# 0  MRT  Vers le 31 décembre 2021 (comme on l'a signalé...
# 1  MLI  Le 31 décembre 2021, l'armée malienne a échoué...
# 2  GHA  Le 31 décembre 2021, des hommes armés ont eu d...
# 3  NGA  Le 31 décembre 2021, une foule a attaqué des a...
# 4  NGA  Le 31 décembre 2021, une foule a démontré et d...
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 6.5 Save final acled dataframe as csv.

# %%
#Save final acled dataframe as csv. NB: Output saved in github repo https://github.com/obengdouglas/DSI-2022/tree/main/module3-nlp-twist/Data as acled21_westafrica_final.csv
acled21_final.to_csv("acled21_westafrica_final.csv", index = False)   #NB: Change excel csv format to csv unicode UTF-8 in order to properly display french accented characters

# %% [markdown]
# ## **7. Conclusion**

# %% [markdown]
# From the analysis,
#
# 1. Nigeria, Burkina Faso and Mali are the top 3 countries for crisis events in West Africa accounting for a combined 78% of all events
# 2. Nigeria, Burkina Faso and Mali are also the top 3 countries for fatalities West Africa accounting for a combined 78% of all events
# 3. Fatalities are randomly distributed throughout the week and the year
# 4. Battles and violence cause the largest number of fatalities
